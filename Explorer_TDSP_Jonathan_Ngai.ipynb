# %% [markdown]
# # 🚗 **Welcome to the <font color='crimson'>** **Explorer Transportation Data Science Project! 🚗**</font>
#  Hosted by the [Northeast Big Data Innovation Hub](https://nebigdatahub.org/about) & [National Student Data Corps](https://nebigdatahub.org/nsdc), in collaboration with the [U.S. Department of Transportation Federal Highway Administration](https://highways.dot.gov/).
#
#
# ---

# %% [markdown]
# ## <font color='crimson'>**Project Information and Background:**</font>

# %% [markdown]
# **Project Description:**
#
# By participating in this project, you are joining a
# community of transportation data science learners interested in making roads safer for vulnerable road users.
#
# The Explorer TDSP has six Milestones, including guided transportation research into a community of interest. Each Milestone can take 1-5 hours, or less, depending on your level of experience.
#
# To learn more about this project, including key highlights, incentives, and important links, [review the TDSP Webpage here](https://nebigdatahub.org/nsdc/tdsp/)!

# %% [markdown]
# ## <font color='crimson'>**How to Get Started:**</font>

# %% [markdown]
# In order to work within this Google Colab Notebook, **please start by clicking on "File" in the top left corner of your notebook, and then "Save a copy in Drive." Rename the file to "Explorer TDSP - Your Full Name."** This will save a copy of the notebook in your personal Google Drive.
#
# You may now begin!

# %% [markdown]
# ---
# ---

# %% [markdown]
# ## <font color='crimson'>**A Quick Introduction to Google Colab**</font>

# %% [markdown]
# Read below for a Google Colab QuickStart:
# - Google Colab is a Python Notebook environment built by Google that's free for all.
# - Colab Notebooks are made up of cells; cells can be either *text* or *code* cells. You can click the +code or +text button at the top of the Notebook to create a new cell.
# - Text cells use a format called [Markdown](https://www.markdownguide.org/getting-started/). Knowledge of Markdown is not required for this project. However, if you'd like to learn more, [check out this Cheatsheet!](https://www.markdownguide.org/cheat-sheet/)
# - Python code is executed in *code* cells. When you want to run your code, hover your cursor over the square brackets in the top left corner of your code cell. You'll notice a play button pop up! (▶) Click the play button to run the code in that cell. Code cells run one at a time.
# - The memory shared across your notebook is called the *Runtime*. You can think of a Runtime as a "code session" where everything you create and execute is temporarily stored.
# - Runtimes will persist for a short period of time, so you are safe if you need to refresh the page, but Google will shutdown a Runtime after enough time has passed. Everything that you have printed out will remain within your Notebook even if the runtime is disconnected.
#
# If this is your first time using Google Colab, we highly recommend reviewing the [NSDC's *Using Google Colab Guide*](https://nebigdatahub.org/wp-content/uploads/2023/04/NSDC-Data-Science-Projects-Introduction-Using-Google-Colab.pdf) before continuing. For a more comprehensive guide, see [Colab's *Welcome To Colaboratory* walkthrough.](https://colab.research.google.com/github/prites18/NoteNote/blob/master/Welcome_To_Colaboratory.ipynb)

# %% [markdown]
# ## <font color='crimson'>**An Introduction to Python Programming**</font>

# %% [markdown]
# Python is a programming language often used to analyze data.
#
# Python is open-source, which means it's free to use and distribute, even for commercial purposes. Python's versatility allows it to be used for web development, data visualization, artificial intelligence, scientific computing, and more.
#
# Python's extensive standard library, along with its powerful third-party packages, enable developers and data scientists to perform a vast array of tasks.
#
# For those looking to dive deeper into Python, here are some valuable resources:
# - [The Official Python Documentation](https://docs.python.org/3/) – Offers comprehensive guides and reference materials for Python leaners.
# - [Real Python](https://realpython.com/) – Provides tutorials and articles for Python developers of all skill levels.
# - [PyCon](https://pycon.org/) – The largest annual gathering for the Python community, which is useful for learning from experts and discovering the latest developments in the Python ecosystem.
# - [Python for Everybody](https://www.py4e.com/) – A book and website by Dr. Charles Severance that offers a free course on Python for beginners.

# %% [markdown]
# **Let's review some essential Python Functions!**
#
# Here are some key functions you'll frequently encounter:
#
# 1. **`head()`**: This function is crucial for getting a quick overview of your dataset. By default, it returns the first five rows, offering a snapshot of your data's structure and values.
#
# 2. **`describe()`**: This provides a summary of the statistical characteristics of your dataset. It's particularly useful for gaining insights into the distribution, mean, standard deviation, and range of numerical columns.
#
# 3. **`sum()`**: This calculates the total sum of a column or a series of numbers, proving essential for quick calculations and aggregations in data analysis.
#
# 4. **`isnull()`**: This helps identify missing or null values in your dataset, allowing for effective data cleaning and preprocessing.
#
# 5. **`value_counts()`**: Understanding the frequency of various values in your dataset is a common task in data science. The `value_counts()` function makes this easy by counting the occurrence of each unique value in a column.
#
# Now that you've reviewed these important concepts, let's dive in to the project!

# %% [markdown]
# ## <font color='crimson'>**Milestone #1 - Data Preparation**</font>
# GOAL: The main goal of this milestone is to set up your environment, install the required packages, learn how to access data and do some basic exploratory data analysis.

# %% [markdown]
# **Step 1:** Setting up libraries and installing packages
#
# A **library** is a collection of code that you can use in your programs, while a **package** is a folder that contains libraries or other packages, organized for easy use.
#
# To install a library, we'll use the following format:
# ```python
#  import <library name> as <shortname>
# ```
# We use a *short name* since it is easier to refer to the package to access functions and also to refer to subpackages within the library. Think of it as a nickname for easier reference!

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import folium

# %% [markdown]
# These are the libraries that will help us throughout this project. We invite you to research each library for a better understanding.
#
# We encourage you to read more about the important and most commonly used libraries like Pandas, Matplotlib, and Seaborn and write a few lines in your own words about what they do. [You may use the Data Science Resource Repository (DSRR) to find resources to get started!](https://nebigdatahub.org/nsdc/data-science-resource-repository/)

# %% [markdown]
# **TO DO:** Write a few lines about what each library does:
#
#
#
#
# > * Pandas:
# > * Matplotlib:
# > * Seaborn:

# %% [markdown]
# **Step 2:** Let’s access our data. We will be using the [NYC OpenData Motor Vehicle Collisions - Crashes dataset](https://data.cityofnewyork.us/Public-Safety/Motor-Vehicle-Collisions-Crashes/h9gi-nx95). According to NYC Open Data, "each row represents a crash event. The Motor Vehicle Collisions data tables contain information from all police reported motor vehicle collisions in NYC." If you need a reminder on how to upload your dataset, [please review helpful hints here.](https://nebigdatahub.org/wp-content/uploads/2023/04/NSDC-Data-Science-Projects-Introduction-Using-Google-Colab.pdf)
#
# Since this is a large dataset, we highly recommend that you upload your data by [mounting your Google Drive](https://colab.research.google.com/notebooks/io.ipynb#scrollTo=u22w3BFiOveA).
#
# To mount your Google Drive, begin by finding the folder icon on the left side of your screen. When you click on this folder icon, you will open the Files window. Click on the icon at the top of the Files window that says "Mount Drive" as you hover over it.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# Next, we will read the data using the `pd.read_csv` function.
# Ensure that you've downloaded the dataset from NYC OpenData, and uploaded the dataset to your Google Drive.

# %% [markdown]
# Hint: Your data's file path describes the location of where your data lives. To locate your data's file path, click on the folder/file-shaped icon on the left side of the Notebook. You'll notice a folder labeled "drive." Search for your Motor Vehicle Collisions Dataset within that folder. Right click on your Dataset to "copy path." Paste that path below.

# %%
# TODO: Read the data using pandas read_csv function
data = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/Explore TDSP/Explore TDSP Data/Motor_Vehicle_Collisions_Crashes.csv")
# Out:
# <ipython-input-3-2eaa03cde5d4>:2: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/Explore TDSP/Explore TDSP Data/Motor_Vehicle_Collisions_Crashes.csv")

# %% [markdown]
# **Step 3:** Let's see what the data looks like. We can use the `head` function which returns the first 5 rows of the dataset.

# %%
# TODO: Print the first 5 rows of the data using head function of pandas
data.head(5)
# Out:
#    CRASH DATE CRASH TIME   BOROUGH ZIP CODE   LATITUDE  LONGITUDE  \
# 0  09/11/2021       2:39       NaN      NaN        NaN        NaN
# 1  03/26/2022      11:45       NaN      NaN        NaN        NaN
# 2  06/29/2022       6:55       NaN      NaN        NaN        NaN
# 3  09/11/2021       9:35  BROOKLYN  11208.0  40.667202 -73.866500
# 4  12/14/2021       8:13  BROOKLYN  11233.0  40.683304 -73.917274
#
#                   LOCATION           ON STREET NAME CROSS STREET NAME  \
# 0                      NaN    WHITESTONE EXPRESSWAY         20 AVENUE
# 1                      NaN  QUEENSBORO BRIDGE UPPER               NaN
# 2                      NaN       THROGS NECK BRIDGE               NaN
# 3    (40.667202, -73.8665)                      NaN               NaN
# 4  (40.683304, -73.917274)          SARATOGA AVENUE    DECATUR STREET
#
#            OFF STREET NAME  ...  CONTRIBUTING FACTOR VEHICLE 2  \
# 0                      NaN  ...                    Unspecified
# 1                      NaN  ...                            NaN
# 2                      NaN  ...                    Unspecified
# 3  1211      LORING AVENUE  ...                            NaN
# 4                      NaN  ...                            NaN
#
#    CONTRIBUTING FACTOR VEHICLE 3  CONTRIBUTING FACTOR VEHICLE 4  \
# 0                            NaN                            NaN
# 1                            NaN                            NaN
# 2                            NaN                            NaN
# 3                            NaN                            NaN
# 4                            NaN                            NaN
#
#    CONTRIBUTING FACTOR VEHICLE 5  COLLISION_ID  VEHICLE TYPE CODE 1  \
# 0                            NaN       4455765                Sedan
# 1                            NaN       4513547                Sedan
# 2                            NaN       4541903                Sedan
# 3                            NaN       4456314                Sedan
# 4                            NaN       4486609                  NaN
#
#    VEHICLE TYPE CODE 2  VEHICLE TYPE CODE 3 VEHICLE TYPE CODE 4  \
# 0                Sedan                  NaN                 NaN
# 1                  NaN                  NaN                 NaN
# 2        Pick-up Truck                  NaN                 NaN
# 3                  NaN                  NaN                 NaN
# 4                  NaN                  NaN                 NaN
#
#   VEHICLE TYPE CODE 5
# 0                 NaN
# 1                 NaN
# 2                 NaN
# 3                 NaN
# 4                 NaN
#
# [5 rows x 29 columns]

# %%
# TODO: Describe the data using the describe function of pandas
desc_stats = data.describe()
desc_stats
# Out:
#            LATITUDE     LONGITUDE  NUMBER OF PERSONS INJURED  \
# count  1.907888e+06  1.907888e+06               2.147422e+06
# mean   4.062023e+01 -7.373853e+01               3.195576e-01
# std    2.054513e+00  3.848699e+00               7.080539e-01
# min    0.000000e+00 -2.013600e+02               0.000000e+00
# 25%    4.066755e+01 -7.397469e+01               0.000000e+00
# 50%    4.072055e+01 -7.392705e+01               0.000000e+00
# 75%    4.076962e+01 -7.386673e+01               0.000000e+00
# max    4.334444e+01  0.000000e+00               4.300000e+01
#
#        NUMBER OF PERSONS KILLED  NUMBER OF PEDESTRIANS INJURED  \
# count              2.147409e+06                   2.147440e+06
# mean               1.541858e-03                   5.813015e-02
# std                4.144117e-02                   2.472256e-01
# min                0.000000e+00                   0.000000e+00
# 25%                0.000000e+00                   0.000000e+00
# 50%                0.000000e+00                   0.000000e+00
# 75%                0.000000e+00                   0.000000e+00
# max                8.000000e+00                   2.700000e+01
#
#        NUMBER OF PEDESTRIANS KILLED  NUMBER OF CYCLIST INJURED  \
# count                  2.147440e+06               2.147440e+06
# mean                   7.623030e-04               2.795980e-02
# std                    2.816714e-02               1.669935e-01
# min                    0.000000e+00               0.000000e+00
# 25%                    0.000000e+00               0.000000e+00
# 50%                    0.000000e+00               0.000000e+00
# 75%                    0.000000e+00               0.000000e+00
# max                    6.000000e+00               4.000000e+00
#
#        NUMBER OF CYCLIST KILLED  NUMBER OF MOTORIST INJURED  \
# count              2.147440e+06                2.147440e+06
# mean               1.206087e-04                2.292502e-01
# std                1.102386e-02                6.692077e-01
# min                0.000000e+00                0.000000e+00
# 25%                0.000000e+00                0.000000e+00
# 50%                0.000000e+00                0.000000e+00
# 75%                0.000000e+00                0.000000e+00
# max                2.000000e+00                4.300000e+01
#
#        NUMBER OF MOTORIST KILLED  COLLISION_ID
# count               2.147440e+06  2.147440e+06
# mean                6.342436e-04  3.212892e+06
# std                 2.754345e-02  1.507079e+06
# min                 0.000000e+00  2.200000e+01
# 25%                 0.000000e+00  3.172980e+06
# 50%                 0.000000e+00  3.709986e+06
# 75%                 0.000000e+00  4.247076e+06
# max                 5.000000e+00  4.784196e+06

# %% [markdown]
# The information above is currently formatted in scientific notation. Need a refresher? [Review how to analyze and convert to and from scientific notation here!](https://www.mathsisfun.com/numbers/scientific-notation.html)
#
# 1. Latitude & Longitude: The latitude and longitude indicate where the crashes are occurring. However, there are some data points with latitude and longitude values of 0, which is likely due to missing or inaccurate data.
#
# 2. Number of Persons Injured: On average, each crash has around 0.305 injuries. The maximum number of injuries in a single crash is 43.
#
# 3. Number of Persons Killed: Fatalities are rare, with an average of 0.00146 deaths per crash. The maximum number of deaths in one crash is 8.
#
# 4. Number of Pedestrians, Cyclists, and Motorists Injured/Killed: These columns provide a breakdown of the injuries and fatalities by type of individual involved.
#
# 5. Collision ID: This is a unique identifier for each crash.

# %% [markdown]
# ---

# %% [markdown]
# ##<font color='crimson'> **Milestone #2 - Data Ethics, Pre-Processing, and Exploration** </font>
# GOAL: The main goal of this milestone is to assess the dataset, find missing values, and decide what to do with those missing data points.

# %% [markdown]
# **Step 1:**
# Before we begin assessing our data for missing values, it is important that we understand the ethical implications surrounding data processing. To best prepare yourself for this module, review one or more of the following resources:
# - [Data Science Ethics Flashcard Video Series](https://youtube.com/playlist?list=PLNs9ZO9jGtUB7XTjXy-ttoo2QSLld9SrV&feature=shared)
# - [What Do I Need to Understand about Data Ethics?](https://www.youtube.com/watch?v=Efy8htCDueE)
# -[Introduction to Data Cleaning](https://www.youtube.com/watch?v=t8WkoGLkdTk)
#
# **TO DO:** Based on the resources above and outside knowledge, what are some potential bias issues related to the availability of data from well-resourced communities as compared to under-resourced communities? How might bias show up in our dataset?
#
# > Answer here: Well-resourced communities may have more data or more detailed data on certain phenomen, leading to erroneous assumptions about the extents of the phenomena said data is meant to describe in well-resourced and under-resourced communities. For example, health records and records of oubreaks during an epidemic may be more detailed when describing well-resourced communities compared to under-resourced communities. This can lead some to interpret the data to mean that there isn't a problem in the under-resourced communities and thus not aide the under-resourced communities when in fact the problem exists, it's just that there's a data discrepancy. For this dataset, bias may show in the number of accidents reported in well-resourced communities vs under-resourced communities.

# %% [markdown]
# **Step 2:**
# Check the dataset for missing values.

# %%
#TODO: Leverage the isnull() and sum() functions to find the number of missing values in each column
missing_values = data.isnull().sum()

#TODO: Turn the missing value counts into percentages
missing_values_percentage = (missing_values / len(data)) * 100

#TODO: Return counts and percentages of missing values in each column
missing_data = pd.DataFrame({'Missing Values': missing_values, 'Percentage (%)': missing_values_percentage})
missing_data.sort_values(by='Percentage (%)', ascending=False)
# Out:
#                                Missing Values  Percentage (%)
# VEHICLE TYPE CODE 5                   2138129       99.566414
# CONTRIBUTING FACTOR VEHICLE 5         2137833       99.552630
# VEHICLE TYPE CODE 4                   2113524       98.420631
# CONTRIBUTING FACTOR VEHICLE 4         2112264       98.361957
# VEHICLE TYPE CODE 3                   1998606       93.069236
# CONTRIBUTING FACTOR VEHICLE 3         1992780       92.797936
# OFF STREET NAME                       1778642       82.826156
# CROSS STREET NAME                      818761       38.127305
# ZIP CODE                               665959       31.011763
# BOROUGH                                665696       30.999516
# ON STREET NAME                         461171       21.475385
# VEHICLE TYPE CODE 2                    420764       19.593749
# CONTRIBUTING FACTOR VEHICLE 2          338763       15.775202
# LOCATION                               239552       11.155236
# LONGITUDE                              239552       11.155236
# LATITUDE                               239552       11.155236
# VEHICLE TYPE CODE 1                     14916        0.694594
# CONTRIBUTING FACTOR VEHICLE 1            7302        0.340033
# NUMBER OF PERSONS KILLED                   31        0.001444
# NUMBER OF PERSONS INJURED                  18        0.000838
# COLLISION_ID                                0        0.000000
# CRASH DATE                                  0        0.000000
# NUMBER OF MOTORIST KILLED                   0        0.000000
# NUMBER OF MOTORIST INJURED                  0        0.000000
# NUMBER OF CYCLIST KILLED                    0        0.000000
# CRASH TIME                                  0        0.000000
# NUMBER OF PEDESTRIANS KILLED                0        0.000000
# NUMBER OF PEDESTRIANS INJURED               0        0.000000
# NUMBER OF CYCLIST INJURED                   0        0.000000

# %% [markdown]
# Here's an overview of the missing values in the dataset:
#
# Columns like VEHICLE TYPE CODE 5, CONTRIBUTING FACTOR VEHICLE 5, VEHICLE TYPE CODE 4, and so on have a high percentage of missing values. This is expected since not all crashes involve multiple vehicles or factors.
#
# OFF STREET NAME and CROSS STREET NAME have significant missing values. This could be due to crashes occurring in locations where these details aren't applicable or weren't recorded.
#
# ZIP CODE, BOROUGH, and ON STREET NAME also have missing values. This might be due to incomplete data entry or crashes occurring in areas where these specifics aren't easily determinable.
#
# LOCATION, LATITUDE, and LONGITUDE have the same count of missing values, indicating that when one is missing, the others are likely missing as well.

# %% [markdown]
# **Step 3:** Create a bar chart to display the top 10 contributing factors (e.g. backing up unsafely, unsafe lane changing, etc.) to crashes within the dataset.

# %%
#TODO: Plot a Bar Chart

top_factors = data['CONTRIBUTING FACTOR VEHICLE 1'].value_counts().head(10)


plt.figure(figsize=(12, 7))
# TODO: Plotting the top contributing factors, fill in x as the index field of the variable 'top_factors'
sns.barplot(x=top_factors.index, y=top_factors.values, palette="magma")
plt.title('Top 10 Contributing Factors to crashes', fontsize=16)
plt.xlabel('Factors', fontsize=14)
plt.ylabel('Counts of Crashes due to Factor', fontsize=14)
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-7-8f8721c8f7e8>:8: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=top_factors.index, y=top_factors.values, palette="magma")

# %% [markdown]
# **TO DO:** Besides for "Unspecified," what are the top 3 contributing factors that cause the most crashes?
#
# > *  Driver Inattention/Distraction
# > *  Failure to Yield Right-of-Way
# > *  Following Too Closely

# %% [markdown]
# **TO DO:** What recommendations would you make to new and current drivers after assessing the above data?
#
# > *   Pay close attention to your surroundings at all times.
# > *   Know your right of way procedures and yield accordingly.
# > *   Maintain a safe distance between yourself and the car infront and behind you.

# %% [markdown]
# **Step 4:** Now, let's create another bar chart to determine which vehicle types were involved in the most crashes.

# %%
# Determine the top vehicle types involved in crashes
top_vehicle_types = data['VEHICLE TYPE CODE 1'].value_counts().head(10)

# Plotting the top vehicle types
plt.figure(figsize=(12, 7))
sns.barplot(x=top_vehicle_types.index, y=top_vehicle_types.values, palette="cividis")
plt.title('Top 10 Vehicle Types Involved in crashes', fontsize=16)
plt.xlabel('Vehicle Type', fontsize=14)
plt.ylabel('Number of crashes', fontsize=14)
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-8-d81efa66963e>:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=top_vehicle_types.index, y=top_vehicle_types.values, palette="cividis")

# %% [markdown]
# **TO DO:** What are the top 3 vehicles that were most involved in crashes?
#
#
# > *   Sedans
# > *   Station Wagons/Sport Utility Vehicles
# > *   Passenger Vehicles

# %% [markdown]
# **TO DO:** Why do you think that "Sedan[s]," "Station Wagon[s]," and "Passenger Vehicle[s]" are involved in a larger number of crashes, injuries, and deaths when compared to the rest of the vehicles? (Think outside the box!)
#
#
# > *  Sedans are the most popular kind of car for people to buy so when it comes to raw number of crashes we would expect more crashes to be attributed to Sedans simply because they're the most commonly found kind of vehicle on the road.
# > *  Similarly most cars on the road are passenger vehicles and Station Wagons are also decently popular so we might expect these kinds of vehicles to hold the highest count in number of accidents simply because there are more of them on the road.
# > *  Additionally, Station Wagons are larger cars with rear sections that are more elevated and thus easily obstructed leading to more accedents.

# %% [markdown]
# **TO DO:** Review the x-axis of the bar chart you created above. </br>
# 1) What do you notice? </br>
# 2) What would you recommend we do to improve the bar chart, based on the x-axis (horizontal axis) and why? </br>
# 3) What recommendation would you make to those who are collecting and/or inputting data into this dataset?
#
#
# > *  1)  The level of detail and items being compared in the x-axis sort of don't fully make sense. For example why compare "Sedan" vs "PASSENGER VEHICLE" when those aren't mutually exlusive and what's the difference between "Taxi" and "TAXI". Additionally the length of the station wagon label makes it hard to read.
# > *  2)  Make sure we're making relevant comparisons by reconciling contradictory labels and maybe combining certain categories into each other. Relabel some of the labels so they are more legible.
# > *  3)  Be more precise in creating values for columns. Ideally have a unified encoding system for categorical datatypes like vehicle type. If you want to classify vehicles as "passenger vs non-passenger" have a column just for that, if you want to classify based off technical vehicle type like "sedan, station wagon" have a column just for that and if you want to classify based of public or private transit like "taxi", "bus", etc devote a column just for that. Try not to blend columns and be more precise in what each column is trying to describe.

# %% [markdown]
# **Step 5:**  A DataFrame is a two-dimensional and potentially heterogeneous tabular data structure with labeled axes (rows and columns). DataFrames allow for storing, manipulating, and retrieving data in a structured form, serving as the primary data structure for a multitude of data processing tasks. It is used with Python libraries like pandas.
#
# Let's graph the *types* of crashes within this dataset and their frequencies. Begin by aggregating your data, convert to [DataFrame](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.html) for simple plotting, and plot.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Aggregating data - Complete for Cyclist and Motorist
types_of_crashes = {
    'Pedestrian Injuries': data['NUMBER OF PEDESTRIANS INJURED'].sum(),
    'Cyclist Injuries': data['NUMBER OF CYCLIST INJURED'].sum(),
    'Motorist Injuries': data['NUMBER OF MOTORIST INJURED'].sum(),
    'Pedestrian Deaths': data['NUMBER OF PEDESTRIANS KILLED'].sum(),
    'Cyclist Deaths': data['NUMBER OF CYCLIST KILLED'].sum(),
    'Motorist Deaths': data['NUMBER OF MOTORIST KILLED'].sum()
}

# Converting to DataFrame for easier plotting - we want the items in the dictionary, use the items function
crash_types_df = pd.DataFrame(list(types_of_crashes.items()), columns=['crash Type', 'Count'])

# Plot
plt.figure(figsize=(12, 7))
sns.barplot(x='Count', y='crash Type', data=crash_types_df, palette="mako")
plt.title('Types of crashes and Their Frequencies')
plt.xlabel('Count')
plt.ylabel('Type of crash')
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-9-1d14d8e1a468>:19: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Count', y='crash Type', data=crash_types_df, palette="mako")

# %% [markdown]
# **TO DO:** Analyze the chart above. What is a recommendation you might make to the Department of Transportation based on this data?
#
#
# > *  Either reduce motor traffic or increase protection for motorists through infrastructure, vehicle design or driving rules. Motor injuries are by far the likely kind of injury to occur when an accident happens.
# > *  Though it's worth pointing out it's possible to have a traffick accident without any pedestrians or cyclists involved but rarely without any motorists involved. Short of driverless cars, more motorist injuries might just be because it's highly unlikely for there to be a traffic accident where a motorist isn't present but still more work can be done to mitigate and reduce damage.

# %% [markdown]
# ---

# %% [markdown]
# ##<font color='crimson'> **Milestone #3 - Time Series Analysis**</font>
# GOAL: The main goal of this milestone is to dive deeper into Time Series Analysis in order to better understand our data's trends over time.

# %% [markdown]
# **Step 1:**
#
# Before we jump into Time Series Analysis (TSA), it's important to understand the basics, including Trends, Seasonality, and Residual Components.
#
# Review one or more of the following resources and tell us what you learned about TSA!
#
# *  [Learn about Time Series patterns here](https://otexts.com/fpp2/tspatterns.html)
# * [Learn about Time Plots here](https://otexts.com/fpp2/time-plots.html)
# *[Learn how to decompose Time Series Data into Trend and Seasonality](https://machinelearningmastery.com/decompose-time-series-data-trend-seasonality/)

# %% [markdown]
# **TO DO:** Write 3-5 sentences about TSA.
# > *  A time series is a series of observations of a variable at different times.
# > *  Time series are most commonly depicted via time plots that plot the values of the variable in question against time.
# > *  Trend is a change in direction acrosss time, seasons are re-occuring patterns of fixed and known frequencies, cycles are re-occuring patterns of unkown and unfixed frequncies.
# > *  Simple abstract models concieve of a time series as composed of a level and noise at least then trends and seasonalities added on top of that. These components can either be summed or multiplied together to make the final time series plot observed.
# > *  Decomposition then allows us to disect a time series plot into the useful components we care about.

# %% [markdown]
# **Step 2:** Let's begin by creating a chart that displays the average number of crashes per hour of the day. This will help us understand whether additional factors are contributing to crashes - i.e. rush hour, school dismissal time, night fall, etc.

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# Load the dataset
file_path = "/content/drive/MyDrive/Colab Notebooks/Explore TDSP/Explore TDSP Data/Motor_Vehicle_Collisions_Crashes.csv"
data = pd.read_csv(file_path)

# Convert 'CRASH DATE' and 'CRASH TIME' to datetime
data['CRASH DATE'] = pd.to_datetime(data['CRASH DATE'])
data['CRASH TIME'] = pd.to_datetime(data['CRASH TIME'], format='%H:%M')

# Time of Day Analysis
data['Hour of Day'] = data['CRASH TIME'].dt.hour

# Group by 'Hour of Day' and calculate the average number of crashes per hour
average_crashes_per_hour = data.groupby('Hour of Day').size() / data['Hour of Day'].nunique()

# Plot the average number of crashes
plt.figure(figsize=(12, 6))
sns.barplot(x=pd.Series(average_crashes_per_hour.index), y=average_crashes_per_hour.values)
plt.title('Average Number of crashes per Hour of Day')
plt.xlabel('Hour of Day')
plt.ylabel('Average Number of crashes')
plt.xticks(range(0, 24))
plt.show()
# Out:
# <ipython-input-10-e0d4b97686fe>:7: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv(file_path)

# %% [markdown]
# **TO DO:** Which time of the day sees the most crashes? Why do you think so?
#
# > *  Around 4pm. Probably because thats when most cars are on the roads and people are tired getting off from work or school.

# %% [markdown]
# **Step 3:**
# Plot a graph to determine how COVID-19 impacted the number of crashes per month, if at all.

# %%
# Convert 'CRASH DATE' to datetime format
data['CRASH DATE'] = pd.to_datetime(data['CRASH DATE'])

# Group by month and year to get the number of crashes per month
monthly_crashes = data.groupby(data['CRASH DATE'].dt.to_period("M")).size()

# Plotting the trend over time
plt.figure(figsize=(15, 7))
monthly_crashes.plot()
plt.title('Number of Crashes per Month', fontsize=16)
plt.xlabel('Date', fontsize=14)
plt.ylabel('Number of Crashes', fontsize=14)
plt.tight_layout()
plt.show()

# %% [markdown]
# **TO DO:** What does your graph tell you about the impact of COVID-19 on the number of crashes per month? Why do you think this occurred?
#
# > *  The graph suggests a correlation between when COVID-19 lockdowns happened and a steep drop in the number of car crashes happening.
# > *  In other words, while seasonal patterns remain the same there was trend of a steep drop in the number of car crashes after pandemic lockdowns.
# > *  This probably occured because the lockdowns kept a lot of poeple inside, hence the number of cars on the road and the number of accidents happening was greatly reduced.

# %% [markdown]
# **Step 4**: Apply time series decomposition to review trends, seasonality, and residuals. New to time series analysis? Review the [Time Series Flashcard video series](https://youtube.com/playlist?list=PLNs9ZO9jGtUAqd0CNKySksPJJaOqYPMvk&feature=shared) here to learn about trends, components, and further analysis!

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from statsmodels.tsa.seasonal import seasonal_decompose

# Count the number of crashes per day, group by CRASH DATE
daily_crashes = data.groupby('CRASH DATE').size()

# Set plot style
sns.set(style="darkgrid")

# Plot the daily crashes time series
plt.figure(figsize=(15, 6))
plt.plot(daily_crashes.values, label='Daily crashes')
plt.title('Daily Motor Vehicle Collisions in NYC')
plt.xlabel('Time')
plt.ylabel('Number of Collisions')
plt.legend()
plt.show()

# Decompose the time series
decomposition = seasonal_decompose(daily_crashes, model='additive', period=365)

# Plot the decomposed components
fig, (ax1, ax2, ax3) = plt.subplots(3, 1, figsize=(15, 12))
decomposition.trend.plot(ax=ax1)
ax1.set_title('Trend')
decomposition.seasonal.plot(ax=ax2)
ax2.set_title('Seasons')
decomposition.resid.plot(ax=ax3)
ax3.set_title('Residuals')
plt.tight_layout()
plt.show()

# %% [markdown]
# The visualizations above provide valuable insights into the time series of daily motor vehicle collisions in New York City:
#
# 1. Time Series Plot: This shows the number of daily crashes over time. You might observe long-term trends, seasonal patterns, or significant outliers.
#
# 2. Decomposed Components:
#
#     2.1 Trend: This graph shows the long-term trend in the data, which can indicate whether crashes are increasing, decreasing, or stable over time.
#
#     2.2 Seasonality: This reveals any regular patterns that repeat over a specific period, such as yearly. It helps identify times of the year with higher or lower crash frequencies.
#
#     2.3 Residuals: These are the irregular components that cannot be attributed to the trend or seasonality. They might include random or unpredictable fluctuations.

# %% [markdown]
# **TO DO:** Based on your *trend graph*, are we seeing an increase or a decrease in crashes between 2014 and 2022?
#
# > *  Based on the trend graph, we see a stark decrease in the number of crashes between 2014 and 2022
#
#
# **TO DO:** Based on your *residual graph*, in what year(s) was there a significant unpredicted fluctuation? Why do you think so?
#
# > *  Based on the residual graph, there was a sudden fluctuation in the early months of 2020 leading to a change in pattern that still persists to this day. This is probably due to the COVID-19 Pandemic Lockdowns keeping everyone inside thus reducing the number of cars on the road on any given day and reducing the number of traffic accidents.

# %% [markdown]
# ---

# %% [markdown]
# ##<font color='crimson'>**Milestone #4 - Geospatial Analysis**</font>
# GOAL: The main goal of this milestone is to explore geospatial aspects of the dataset and get comfortable with regional analysis and geospatial visualizations.

# %% [markdown]
# **Step 1:** Before beginning this Milestone, we highly recommend that you review the [NSDC Geospatial Analysis Flashcard Video series](https://www.youtube.com/playlist?list=PLNs9ZO9jGtUAX_2g1-OJp8VkmVum6DqqP) if you are new to Geospatial Analysis!
#
# Let's build a bar chart to compare and analyze the number of crashes across the five boroughs: Brooklyn (also known as Kings County), Queens, Manhattan, Bronx, and Staten Island.

# %%
#TODO: Plot a bar chart to compare the number of crashes that occurred in each of the five boroughs.
# Set style
sns.set_style("whitegrid")

# Plotting the distribution of crashes by borough
plt.figure(figsize=(12, 7))
# Find the count of unique values of BOROUGHS. Hint: Use value_count function.
borough_count = data['BOROUGH'].value_counts()
sns.barplot(x=borough_count.index, y=borough_count.values, palette="viridis")
plt.title('Distribution of Crashes by Borough', fontsize=16)
plt.xlabel('Borough', fontsize=14)
plt.ylabel('Number of Crashes', fontsize=14)
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-13-4f14068022f4>:9: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=borough_count.index, y=borough_count.values, palette="viridis")

# %% [markdown]
# **TO DO:** Which borough has the highest number of crashes? Which borough has the lowest?
#
# > * Highest: Brooklyn
# > * Lowest: Staten Island
#
#
# **TO DO:** Are there any reasons that you think a certain borough has a higher or lower number of crashes? What are some factors that may be causing this?
#
# > *  Population density is probably a causal factor at work, more people means more cars which means more crashes.
# > *  Another causal factor might be infrastructure, areas with more tightly packed and less safe road infrastructure might mean more crashes in those areas.

# %% [markdown]
# **Step 2:** Heatmaps are graphical representations that use color coding to represent different values and variables. Let's leverage a heatmap to determine the most dangerous intersections in the dataset. (**Note: the below cell may take a few minutes to run**)

# %%
#TODO: Create a heatmap leveraging the latitude and longitude variables to determine where the most crashes are occurring
from folium.plugins import HeatMap

# Drop rows with missing latitude and longitude values
data_geo = data.dropna(subset=['LATITUDE', 'LONGITUDE'])

# Create a base map
m = folium.Map(location=[40.730610, -73.935242], zoom_start=10)  # Centered around NYC

# Create a heatmap
heat_data = [[row['LATITUDE'], row['LONGITUDE']] for index, row in data_geo.iterrows()]
HeatMap(heat_data, radius=8, max_zoom=13).add_to(m)

m.save("Heatmap.html")

# %% [markdown]
# **TO DO:** On the left side of your screen, you will see an icon that represents a folder or a file. Click on that icon to find the file titled "Heatmap.html". Click on the three dots next to your file and download your heatmap! Open the file once downloaded to see your creation.
#
# When looking at your heatmap, where do you see a concentration of crashes?
#
#
# > *  Manhatten has a higher concentration of crashes compared to surrounding areas.

# %% [markdown]
# **Step 3:** Next, we will begin "Severity Mapping." We'll plot crashes on the map and code them based on severity, distinguishing between crashes that resulted in injuries and those that led to fatalities. This will give us a visual representation of where severe crashes tend to occur. </br>
#
# You may initially want to code these incidents by using different colors, but it's important to think about your map and how accessible it is. Will a color-coded map be easy to read for everyone? Let's make a map that's inclusive for people with color blindness by also creating differently-shaped markers (squares, circles, and triangles) for crashes, injuries, and fatalities.

# %%
#TODO: Continue building your heatmap
# Sample a subset of the data for visualization
sample_data_severity = data_geo.sample(n=1000, random_state=42)

# Create a base map
m_severity = folium.Map(location=[40.730610, -73.935242], zoom_start=10)

# Add crashes to the map with color coding and shape coding based on severity
for index, row in sample_data_severity.iterrows():
    if row['NUMBER OF PERSONS KILLED'] > 0:
        color = "red"  # Fatalities

        folium.features.RegularPolygonMarker(
          location=[row['LATITUDE'], row['LONGITUDE']],
          number_of_sides=3,
          radius=5,
          gradient = False,
          color=color,
          fill=True,
          fill_color=color
        ).add_to(m_severity)


    elif row['NUMBER OF PERSONS INJURED'] > 0:
        color = "yellow"  # Injuries
        folium.CircleMarker(
          location=[row['LATITUDE'], row['LONGITUDE']],
          radius=5,
          color=color,
          fill=True,
          fill_color=color
       ).add_to(m_severity)
    else:
        color = "green"  # No injuries or fatalities
        folium.features.RegularPolygonMarker(
          location=[row['LATITUDE'], row['LONGITUDE']],
          number_of_sides=4,
          radius=5,
          gradient = False,
          color=color,
          fill=True,
          fill_color=color
        ).add_to(m_severity)


m_severity.save("severity.html")

# %% [markdown]
# **TO DO:** On the left side of your screen, you will see an icon that represents a folder or a file. Follow the same steps as above to download the "Severity.html" file.
#
# **TO DO:** Which intersection(s) seem to be the most dangerous?
#
# > *  Intersections or portions of roads leading into intersections.
# > *  Usually intersections between a smaller and a larger road, though not necessarily a high way intersection.

# %% [markdown]
# ---
# ---

# %% [markdown]
# ##<font color='crimson'>  **Milestone #5 - Self-Guided Research Question**</font>
# GOAL: In this Milestone, you will be prompted to take what you’ve learned throughout this project, build your own research question, and create a visualization(s) or model(s) to support your research goals.

# %% [markdown]
# You may create your visualization(s) in this Colab Notebook, or in Excel, Tableau, PowerBI, etc. Choose whichever medium you are most comfortable with! Be creative!
#
# For participants who are comfortable with advanced data science techniques, we welcome you to leverage additional datasets, if desired. We highly recommend using pre-cleaned datasets from open data sources, like Kaggle.com.
#
# If you have any questions or get stuck, please email nsdc@nebigdatahub.org with your queries. We're here to help!

# %% [markdown]
# **Step 1:** Review the dataset(s) that you will be using. As you explore, [consider the research question you want to answer](https://libraries.indiana.edu/sites/default/files/Develop_a_Research_Question.pdf)! Additionally, think about [who you are telling your data's story to](https://hbr.org/2013/04/how-to-tell-a-story-with-data). Your final audience may contain a group of transportation professionals, data scientists, peers, and the general public. Think about how would you frame your analysis differently for each of these groups.

# %% [markdown]
# **TO DO:** List one or more research questions here that you are considering.
#
# > *  What factors make it more likely for there to be deaths vs injuries in a crash? (maybe built a logistic classifier or multivariate regression model)
# > *  Maybe I can one-hot encode whether or not a crash is happening in top 3 most dangerous boroughs, top 3 most dangerous times and is a sedan or not or is at a risky intersection or not.
#
# > * Do certain boroughs have certain trends in crashes across time? Whats the number of crashes we can expect to see in different boroughs?
# > * Maybe I can do a time series decomposition and poisson process.

# %% [markdown]
# **Step 2:** Now, think about what type of analysis you'd like to complete. Are you interested in looking at time series forecasting? Do you have additional maps in mind that you'd like to create? Is there a certain zip code or region you'd like to dive deeper into?
#
# If you happen to be stuck, here are some examples that you can use or can guide you in choosing your research question!
#
# **Examples:**
# - How many crashes, injuries, and/or fatalies occurred in a zip code of interest?
# - Which zip code sees the highest amount of crashes and what recommendations can you offer to help that community? Is it an underserved community?
# - Do more crashes occur in underrepresented communities? Support your conclusion.
# - Which day of the week sees the most crashes, injuries, and/or fatalities? (Hint: use the same method we used when we were analyzing the average number of crashes at different times of the day!)
# - Does the geometric features of an intersection (90 degree intersection vs skewed intersection) affect the number of crashes that occur?
#
# Be creative and think outside the box!

# %% [markdown]
# **Step 3:** Now that you've decided on your transportation research question, [explore the various types of visualizations you can create to support your research](https://datavizcatalogue.com/). You may create visualizations in this Google Colab notebook, Excel, R, SQL, PowerBI, Tableau, etc. Choose a program you are comfortable with!
#
# You may also choose to build a model or leverage a different data science technique based on your experience level.

# %% [markdown]
# **Step 4:** Consider the **accessibility** of the graphs, charts, maps, or models you are interested in building. Use the tools below to learn more!
# * How does your visualization appear to people [who may not be able to distinguish between muted colors or see your chart at all?](https://chartability.fizz.studio/)
# *[Color Contrast Checker](https://policyviz.com/2022/11/01/color-contrast-checker-in-excel/)
# *[SAS Graphics Accelerator](https://support.sas.com/software/products/graphics-accelerator/index.html)
# *[TwoTone Data Sonification Tool](https://twotone.io/about/)
# *[Making Visual Studio Accessible](https://code.visualstudio.com/docs/editor/accessibility)

# %% [markdown]
# To make visualizations more inclusive for people with color blindness, you can choose a color palette that is colorblind-friendly. `Seaborn`, a Python visualization library, provides several palettes that are designed to be perceptible by those with color vision deficiencies. Seaborn's `cubehelix` palette is a good choice, as it was designed specifically with color blindness in mind.

# %% [markdown]
# **Step 5:** Begin your research! Give yourself plenty of time to build your visualization or model. If you have any questions along the way, please email nsdc@nebigdatahub.org or write a message in the #[tdsp-community Slack Channel](https://join.slack.com/t/nsdcorps/shared_invite/zt-1h64t1e2p-La0AgU_HhymWUEGFQEcb3w).

# %% [markdown]
# **TO DO:** List the research question(s) you've chosen and why! Maybe you chose this question because it can help a community of interest or because it is similar to research you've completed in a class setting. Share your thoughts below.
#
# > *  What boroughs are most predictive of having crashes that result in injury
# > *  What are trends
# > *  Something that led me to do poisson process

# %% [markdown]
# **TO DO:** Build a visualization, model, or use other statistical methods to gain insights into your data and to support your research question.

# %% [markdown]
# **EDA for Examining Accidents with Injuries or Deaths**: In this section I embark on some exporatory data analysis to visualize variables and look for possible trends/correlations when it comes to accidents with injuries or deaths.

# %%
data.columns
# Out:
# Index(['CRASH DATE', 'CRASH TIME', 'BOROUGH', 'ZIP CODE', 'LATITUDE',
#        'LONGITUDE', 'LOCATION', 'ON STREET NAME', 'CROSS STREET NAME',
#        'OFF STREET NAME', 'NUMBER OF PERSONS INJURED',
#        'NUMBER OF PERSONS KILLED', 'NUMBER OF PEDESTRIANS INJURED',
#        'NUMBER OF PEDESTRIANS KILLED', 'NUMBER OF CYCLIST INJURED',
#        'NUMBER OF CYCLIST KILLED', 'NUMBER OF MOTORIST INJURED',
#        'NUMBER OF MOTORIST KILLED', 'CONTRIBUTING FACTOR VEHICLE 1',
#        'CONTRIBUTING FACTOR VEHICLE 2', 'CONTRIBUTING FACTOR VEHICLE 3',
#        'CONTRIBUTING FACTOR VEHICLE 4', 'CONTRIBUTING FACTOR VEHICLE 5',
#        'COLLISION_ID', 'VEHICLE TYPE CODE 1', 'VEHICLE TYPE CODE 2',
#        'VEHICLE TYPE CODE 3', 'VEHICLE TYPE CODE 4', 'VEHICLE TYPE CODE 5',
#        'Hour of Day'],
#       dtype='object')

# %%
def exclude_outliers(df, col):

  Q1 = df[col].quantile(0.25)
  Q3 = df[col].quantile(0.75)
  cleaned = df[(df[col] <= Q3 + 1.5 * (Q3 - Q1)) & (df[col] >= Q1 - 1.5 * (Q3 - Q1))]
  return cleaned

# %%
print(data['NUMBER OF PERSONS INJURED'].unique())
print(data['NUMBER OF PERSONS KILLED'].unique())
# Out:
# [ 2.  1.  0.  4.  3.  5.  7.  6.  9. 18.  8. 11. 17. 10. 14. 15. 12. 13.
#  40. 16. nan 20. 22. 31. 19. 27. 32. 24. 43. 21. 23. 34. 25.]
# [ 0.  1.  2.  3.  4. nan  8.  5.]

# %%
 #testing to see if number of persons injured and killed is a good metric
print(all((data['NUMBER OF PERSONS INJURED'] ==  data['NUMBER OF PEDESTRIANS INJURED'] + data['NUMBER OF CYCLIST INJURED'] + data['NUMBER OF MOTORIST INJURED'])))
print(all((data['NUMBER OF PERSONS KILLED'] ==  data['NUMBER OF PEDESTRIANS KILLED'] + data['NUMBER OF CYCLIST KILLED'] + data['NUMBER OF MOTORIST KILLED'])))
# Out:
# False
# False

# %%
not_equal = data[data['NUMBER OF PERSONS INJURED'] !=  (data['NUMBER OF PEDESTRIANS INJURED'] + data['NUMBER OF CYCLIST INJURED'] + data['NUMBER OF MOTORIST INJURED'])]
not_equal[['NUMBER OF PERSONS INJURED', 'NUMBER OF PEDESTRIANS INJURED', 'NUMBER OF CYCLIST INJURED', 'NUMBER OF MOTORIST INJURED']]
# Out:
#          NUMBER OF PERSONS INJURED  NUMBER OF PEDESTRIANS INJURED  \
# 47                             1.0                              0
# 284                            1.0                              0
# 356                            1.0                              0
# 385                            1.0                              0
# 409                            1.0                              0
# ...                            ...                            ...
# 2147011                        1.0                              0
# 2147060                        1.0                              0
# 2147176                        1.0                              0
# 2147292                        1.0                              0
# 2147345                        1.0                              0
#
#          NUMBER OF CYCLIST INJURED  NUMBER OF MOTORIST INJURED
# 47                               0                           0
# 284                              0                           0
# 356                              0                           0
# 385                              0                           0
# 409                              0                           0
# ...                            ...                         ...
# 2147011                          0                           0
# 2147060                          0                           0
# 2147176                          0                           0
# 2147292                          0                           0
# 2147345                          0                           0
#
# [9083 rows x 4 columns]

# %%
equal = data[data['NUMBER OF PERSONS INJURED'] ==  (data['NUMBER OF PEDESTRIANS INJURED'] + data['NUMBER OF CYCLIST INJURED'] + data['NUMBER OF MOTORIST INJURED'])]
equal[['NUMBER OF PERSONS INJURED', 'NUMBER OF PEDESTRIANS INJURED', 'NUMBER OF CYCLIST INJURED', 'NUMBER OF MOTORIST INJURED']]
# Out:
#          NUMBER OF PERSONS INJURED  NUMBER OF PEDESTRIANS INJURED  \
# 0                              2.0                              0
# 1                              1.0                              0
# 2                              0.0                              0
# 3                              0.0                              0
# 4                              0.0                              0
# ...                            ...                            ...
# 2147435                        0.0                              0
# 2147436                        0.0                              0
# 2147437                        2.0                              0
# 2147438                        1.0                              1
# 2147439                        0.0                              0
#
#          NUMBER OF CYCLIST INJURED  NUMBER OF MOTORIST INJURED
# 0                                0                           2
# 1                                0                           1
# 2                                0                           0
# 3                                0                           0
# 4                                0                           0
# ...                            ...                         ...
# 2147435                          0                           0
# 2147436                          0                           0
# 2147437                          0                           2
# 2147438                          0                           0
# 2147439                          0                           0
#
# [2138357 rows x 4 columns]

# %%
pers_injur_only = data[(data['NUMBER OF PERSONS INJURED'] >= 1) & (data['NUMBER OF PEDESTRIANS INJURED'] == 0) & (data['NUMBER OF CYCLIST INJURED'] == 0) & (data['NUMBER OF MOTORIST INJURED'] == 0)]
pers_injur_only[['NUMBER OF PERSONS INJURED', 'NUMBER OF PEDESTRIANS INJURED', 'NUMBER OF CYCLIST INJURED', 'NUMBER OF MOTORIST INJURED']]
# Out:
#          NUMBER OF PERSONS INJURED  NUMBER OF PEDESTRIANS INJURED  \
# 47                             1.0                              0
# 284                            1.0                              0
# 356                            1.0                              0
# 385                            1.0                              0
# 409                            1.0                              0
# ...                            ...                            ...
# 2147011                        1.0                              0
# 2147060                        1.0                              0
# 2147176                        1.0                              0
# 2147292                        1.0                              0
# 2147345                        1.0                              0
#
#          NUMBER OF CYCLIST INJURED  NUMBER OF MOTORIST INJURED
# 47                               0                           0
# 284                              0                           0
# 356                              0                           0
# 385                              0                           0
# 409                              0                           0
# ...                            ...                         ...
# 2147011                          0                           0
# 2147060                          0                           0
# 2147176                          0                           0
# 2147292                          0                           0
# 2147345                          0                           0
#
# [8523 rows x 4 columns]

# %%
data['Num Injured Cleaned'] = data['NUMBER OF PEDESTRIANS INJURED'] + data['NUMBER OF CYCLIST INJURED'] + data['NUMBER OF MOTORIST INJURED']
data['Num Killed Cleaned'] = data['NUMBER OF PEDESTRIANS KILLED'] + data['NUMBER OF CYCLIST KILLED'] + data['NUMBER OF MOTORIST KILLED']

# %%
injured_or_dead = data[(data['Num Injured Cleaned'] >= 1) | (data['Num Killed Cleaned'] >= 1)]
injured_only = data[(data['Num Injured Cleaned'] >= 1) & (data['Num Killed Cleaned'] == 0)]
dead_only = data[(data['Num Injured Cleaned'] == 0) & (data['Num Killed Cleaned'] >= 1)]
injured_and_dead = data[(data['Num Injured Cleaned'] >= 1) & (data['Num Killed Cleaned'] >= 1)]
no_injured_or_dead = data[(data['Num Injured Cleaned'] == 0) & (data['Num Killed Cleaned'] == 0)]

injured_marginal = data[data['Num Injured Cleaned'] >= 1]
dead_marginal = data[data['Num Killed Cleaned'] >= 1]

# %%
IoD = len(injured_or_dead)
OI = len(injured_only)
OD = len(dead_only)
ID = len(injured_and_dead)
NID = len(no_injured_or_dead)

print(f"Number of entries with INJURIES OR DEATHS: {IoD} / {IoD/len(data)*100}% of all entries")
print(f"Number of entries with ONLY INJURIES: {OI} / {OI/len(data)*100}% of all entries")
print(f"Number of entries with ONLY DEATHS: {OD} / {OD/len(data)*100}% of all entries")
print(f"Number of entries with INJURIES AND DEATHS: {ID} / {ID/len(data)*100}% of all entries")
print(f"Number of entries with NO INJURIES OR DEATHS: {NID} / {NID/len(data)*100}% of all entries")
# Out:
# Number of entries with INJURIES OR DEATHS: 500211 / 23.29336326044034% of all entries
# Number of entries with ONLY INJURIES: 497087 / 23.14788771746824% of all entries
# Number of entries with ONLY DEATHS: 2332 / 0.10859441940170621% of all entries
# Number of entries with INJURIES AND DEATHS: 792 / 0.03688112357039079% of all entries
# Number of entries with NO INJURIES OR DEATHS: 1647229 / 76.70663673955967% of all entries

# %% [markdown]
# It seems that most "accidents" do not involve any deaths or injuries. I should be noted however that not all "accidents" are created equal. Some "accidents" may be way more intense in scale and what counts as an "accident" is always something to consider, especially given the information in the plot of types of crashes and their frequences.
#
# Now let's examine different features we could use for our logistic regression model. Features for now include:
# > * 'BOROUGH'
# > * 'Hour of Day'
#
# Other features that may be included:
# > * Vehicle Type: Not self-consistent
# > * Reason for Crash: Would be painful to one-hot-encode

# %%
def standard_cleaner(df, col, custom_value=None):
  rv = df.copy()
  col = [col] if isinstance(col, str) else col

  for c in col:
      if custom_value is None:
          rv = rv[~rv[c].isna()]
      else:
          rv = rv[rv[c] != custom_value]

  return rv

# %%
#define col 'Unscathed' indicating no injuries or deaths
data['Unscathed'] = (data['Num Injured Cleaned'] + data['Num Killed Cleaned']).apply(lambda x: 1 if x == 0 else 0)
data['Unscathed'].value_counts()
# Out:
# Unscathed
# 1    1647229
# 0     500211
# Name: count, dtype: int64

# %%
cleaned_borough_data = data.copy()
cleaned_borough_data['BOROUGH'] = cleaned_borough_data['BOROUGH'].fillna('Unspecified')
grouped_borough_data = cleaned_borough_data.groupby(['BOROUGH', 'Unscathed']).size().reset_index().rename(columns={0: 'Count'})

sns.set_style("whitegrid")
plt.figure(figsize=(12, 7))

sns.barplot(grouped_borough_data, x='Unscathed', y='Count', hue='BOROUGH')
plt.title('Distribution of Unscathed Crashes by Borough', fontsize=16)
plt.xlabel('Unscathed', fontsize=14)
plt.ylabel('Count', fontsize=14)
# Out:
# Text(0, 0.5, 'Count')

# %%
proportion_grouped_borough_data = cleaned_borough_data.groupby(['BOROUGH', 'Unscathed']).size() / cleaned_borough_data.groupby('BOROUGH').size()
proportion_grouped_borough_data = proportion_grouped_borough_data.reset_index().rename(columns={0: 'Proportion'})
proportion_grouped_borough_data = proportion_grouped_borough_data[proportion_grouped_borough_data['Unscathed'] == 0]

sns.set_style("whitegrid")
plt.figure(figsize=(12, 7))

sns.barplot(proportion_grouped_borough_data, x='BOROUGH', y='Proportion')
plt.title('Proportions of crashes with injuries or deaths by Borough', fontsize=16)
plt.xlabel('Borough', fontsize=14)
plt.ylabel('Proportion with injuries or deaths', fontsize=14)
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %%
cleaned_crash_cause = data[data['CONTRIBUTING FACTOR VEHICLE 1'].isin(top_factors.index)]
proportion_crash_cause = cleaned_crash_cause.groupby(['CONTRIBUTING FACTOR VEHICLE 1', 'Unscathed']).size() / cleaned_crash_cause.groupby('CONTRIBUTING FACTOR VEHICLE 1').size()
proportion_crash_cause = proportion_crash_cause.reset_index().rename(columns={0: 'Proportion'})
proportion_crash_cause = proportion_crash_cause[proportion_crash_cause['Unscathed'] == 0]

sns.set_style("whitegrid")
plt.figure(figsize=(12, 7))

sns.barplot(proportion_crash_cause, x='CONTRIBUTING FACTOR VEHICLE 1', y='Proportion')
plt.title('Proportions of crashes with injuries or deaths by contributing factor', fontsize=16)
plt.xlabel('Contributing Factor', fontsize=14)
plt.ylabel('Proportion with injuries or deaths', fontsize=14)
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %%
top_vehicle_types
# Out:
# VEHICLE TYPE CODE 1
# Sedan                                  608801
# Station Wagon/Sport Utility Vehicle    478152
# PASSENGER VEHICLE                      416206
# SPORT UTILITY / STATION WAGON          180291
# Taxi                                    53650
# 4 dr sedan                              40181
# Pick-up Truck                           36426
# TAXI                                    31911
# Box Truck                               25432
# VAN                                     25266
# Name: count, dtype: int64

# %%
cleaned_vehicle_type = data[data['VEHICLE TYPE CODE 1'].isin(top_vehicle_types.index)]
proportion_vehicle_type = cleaned_vehicle_type.groupby(['VEHICLE TYPE CODE 1', 'Unscathed']).size() / cleaned_vehicle_type.groupby('VEHICLE TYPE CODE 1').size()
proportion_vehicle_type = proportion_vehicle_type.reset_index().rename(columns={0: 'Proportion'})
proportion_vehicle_type = proportion_vehicle_type[proportion_vehicle_type['Unscathed'] == 0]

sns.set_style("whitegrid")
plt.figure(figsize=(12, 7))

sns.barplot(proportion_vehicle_type, x='VEHICLE TYPE CODE 1', y='Proportion')
plt.title('Proportions of crashes with injuries or deaths by contributing factor', fontsize=16)
plt.xlabel('Contributing Factor', fontsize=14)
plt.ylabel('Proportion with injuries or deaths', fontsize=14)
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %% [markdown]
# Now we build the model itself. This entails:
# > * Feature Engineering Pipeline
# > * Training, Validation and Test Set data partitioning
# > * Testing and Fine-Tuning

# %%
from sklearn.preprocessing import OneHotEncoder
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, roc_curve, auc, confusion_matrix, classification_report
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import train_test_split

import numpy as np

# %% [markdown]
# **Model Construction**: Now, we will create a Logistics Regression Model to predict whether or not a accident will lead to injuries and/or death.

# %%
def feature_engine_inital(data, is_test_set=False, enc=None):
    if not is_test_set:
        #processing for the training set
        #training set can involve references to response variable 'Unscathed')
        #can remove data points for training data
        copy = data.copy()
        copy['BOROUGH'] = copy['BOROUGH'].fillna('Unspecified')
        # cleaned_vehicle_data = standard_cleaner(cleaned_borough_data, 'CONTRIBUTING FACTOR VEHICLE 1', 'Unspecified') no longer necessary

        #initialize the encoder only once for training set
        if enc is None:
            enc = OneHotEncoder()  #avoiding dummy variable trap by dropping one column

        #fit the encoder on the training data
        enc.fit(copy[['BOROUGH']])
        encoded_data = enc.transform(copy[['BOROUGH']]).toarray()
        encoded_data_df = pd.DataFrame(encoded_data, columns=enc.get_feature_names_out(['BOROUGH']))

        #combine the encoded columns with the original data, removing 'BOROUGH'
        data_w_ohe = copy[['Hour of Day']].reset_index().join(encoded_data_df)

        X = data_w_ohe
        Y = np.array(copy['Unscathed'])


        return X, Y, enc

    else:
        if enc is None:
            raise ValueError("An initialized encoder must be passed when processing the test set.")

        #processing for the test set
        #test set should not involve the response variable 'Unscathed' or removing rows, model must operate on data independent of response
        #cannot remove data points for test set, model must make a prediction for every data point as if it were functioning in the real world
        copy = data.copy()
        copy['BOROUGH'] = copy['BOROUGH'].fillna('Unspecified')

        encoded_data = enc.transform(copy[['BOROUGH']]).toarray()
        encoded_data_df = pd.DataFrame(encoded_data, columns=enc.get_feature_names_out(['BOROUGH']))

        #combine the encoded columns with the test data, removing 'BOROUGH'
        data_w_ohe = copy[['Hour of Day']].reset_index().join(encoded_data_df)

        #return only predictors (X) for the test set
        X = data_w_ohe
        return X

# %%
data.columns
# Out:
# Index(['CRASH DATE', 'CRASH TIME', 'BOROUGH', 'ZIP CODE', 'LATITUDE',
#        'LONGITUDE', 'LOCATION', 'ON STREET NAME', 'CROSS STREET NAME',
#        'OFF STREET NAME', 'NUMBER OF PERSONS INJURED',
#        'NUMBER OF PERSONS KILLED', 'NUMBER OF PEDESTRIANS INJURED',
#        'NUMBER OF PEDESTRIANS KILLED', 'NUMBER OF CYCLIST INJURED',
#        'NUMBER OF CYCLIST KILLED', 'NUMBER OF MOTORIST INJURED',
#        'NUMBER OF MOTORIST KILLED', 'CONTRIBUTING FACTOR VEHICLE 1',
#        'CONTRIBUTING FACTOR VEHICLE 2', 'CONTRIBUTING FACTOR VEHICLE 3',
#        'CONTRIBUTING FACTOR VEHICLE 4', 'CONTRIBUTING FACTOR VEHICLE 5',
#        'COLLISION_ID', 'VEHICLE TYPE CODE 1', 'VEHICLE TYPE CODE 2',
#        'VEHICLE TYPE CODE 3', 'VEHICLE TYPE CODE 4', 'VEHICLE TYPE CODE 5',
#        'Hour of Day', 'Num Injured Cleaned', 'Num Killed Cleaned',
#        'Unscathed'],
#       dtype='object')

# %%
train_data, test_data = train_test_split(data, test_size=0.2, random_state=42, stratify=data['Unscathed'])

print(f"Training set: {len(train_data)} samples")
print(f"Test set: {len(test_data)} samples")
# Out:
# Training set: 1717952 samples
# Test set: 429488 samples

# %%
Y_test = test_data['Unscathed']

# %%
X_train_initial, Y_train_initial, trained_enc_initial = feature_engine_inital(train_data)
X_test_initial = feature_engine_inital(test_data, is_test_set=True, enc=trained_enc_initial)

# %%
initial_model = LogisticRegression(max_iter=1000, fit_intercept=False) #because we one hot encoded and did not drop
initial_model.fit(X_train_initial, Y_train_initial)
# Out:
# LogisticRegression(fit_intercept=False, max_iter=1000)

# %%
initial_model.coef_
# Out:
# array([[2.38088692e-07, 3.01683875e-02, 1.84372098e-01, 1.51670965e-01,
#         9.56623232e-01, 4.87629796e-01, 8.47171662e-02, 5.73767823e-01]])

# %%
initial_train_predictions = initial_model.predict(X_train_initial)
initial_training_accuracy = np.mean(initial_train_predictions == Y_train_initial)
initial_training_accuracy
# Out:
# 0.7670662509779086

# %%
initial_test_predictions = initial_model.predict(X_test_initial)
initial_test_accuracy = np.mean(initial_test_predictions == Y_test)
initial_test_accuracy
# Out:
# 0.7670668330663488

# %%
print(classification_report(Y_train_initial, initial_train_predictions))
print(confusion_matrix(Y_train_initial, initial_train_predictions))
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00    400169
#            1       0.77      1.00      0.87   1317783
#
#     accuracy                           0.77   1717952
#    macro avg       0.38      0.50      0.43   1717952
# weighted avg       0.59      0.77      0.67   1717952
#
# [[      0  400169]
#  [      0 1317783]]

# %%
#it seems that most of the predictions are 1s, probably because the training set contained mostly 'Unscathed' entries
pd.Series(initial_train_predictions).value_counts()
# Out:
# 1    1717952
# Name: count, dtype: int64

# %% [markdown]
# Now let's fine tune a bit.

# %%
def feature_engine_final(data, is_test_set=False, enc=None):
    if not is_test_set:
        #processing for the training set
        #training set can involve references to response variable 'Unscathed')
        #can remove data points for training data
        copy = data.copy()
        copy['Time from Peak Hour'] = average_crashes_per_hour.sort_values(ascending=False).index[0] - copy['Hour of Day']
        copy['BOROUGH'] = copy['BOROUGH'].fillna('Unspecified')
        copy['VEHICLE TYPE CODE 1'] = copy['VEHICLE TYPE CODE 1'].apply(lambda x: x if x in set(top_vehicle_types.index) else 'Other')
        copy['CONTRIBUTING FACTOR VEHICLE 1'] = copy['CONTRIBUTING FACTOR VEHICLE 1'].apply(lambda x: x if x in set(top_factors.index) else 'Other')

        #initialize the encoder only once for training set
        if enc is None:
            enc = OneHotEncoder(drop='first')  #avoiding collinearity by dropping one column per variable

        #fit the encoder on the training data
        enc.fit(copy[['BOROUGH', 'VEHICLE TYPE CODE 1', 'CONTRIBUTING FACTOR VEHICLE 1']])
        encoded_data = enc.transform(copy[['BOROUGH', 'VEHICLE TYPE CODE 1', 'CONTRIBUTING FACTOR VEHICLE 1']]).toarray()
        encoded_data_df = pd.DataFrame(encoded_data, columns=enc.get_feature_names_out(['BOROUGH', 'VEHICLE TYPE CODE 1', 'CONTRIBUTING FACTOR VEHICLE 1']))

        #combine the encoded columns with the original data, removing 'BOROUGH'
        data_w_ohe = copy[['Time from Peak Hour']].reset_index().join(encoded_data_df)

        X = data_w_ohe
        Y = np.array(copy['Unscathed'])


        return X, Y, enc

    else:
        if enc is None:
            raise ValueError("An initialized encoder must be passed when processing the test set.")

        #processing for the test set
        #test set should not involve the response variable 'Unscathed' or removing rows, model must operate on data independent of response
        #cannot remove data points for test set, model must make a prediction for every data point as if it were functioning in the real world
        copy = data.copy()
        copy['Time from Peak Hour'] = average_crashes_per_hour.sort_values(ascending=False).index[0] - copy['Hour of Day']
        copy['BOROUGH'] = copy['BOROUGH'].fillna('Unspecified')
        copy['VEHICLE TYPE CODE 1'] = copy['VEHICLE TYPE CODE 1'].apply(lambda x: x if x in set(top_vehicle_types.index) else 'Other')
        copy['CONTRIBUTING FACTOR VEHICLE 1'] = copy['CONTRIBUTING FACTOR VEHICLE 1'].apply(lambda x: x if x in set(top_factors.index) else 'Other')

        encoded_data = enc.transform(copy[['BOROUGH', 'VEHICLE TYPE CODE 1', 'CONTRIBUTING FACTOR VEHICLE 1']]).toarray()
        encoded_data_df = pd.DataFrame(encoded_data, columns=enc.get_feature_names_out(['BOROUGH', 'VEHICLE TYPE CODE 1', 'CONTRIBUTING FACTOR VEHICLE 1']))

        #combine the encoded columns with the test data, removing 'BOROUGH'
        data_w_ohe = copy[['Time from Peak Hour']].reset_index().join(encoded_data_df)

        #return only predictors (X) for the test set
        X = data_w_ohe
        return X

# %%
X_train, Y_train, trained_enc = feature_engine_final(train_data)
X_test = feature_engine_final(test_data, is_test_set=True, enc=trained_enc)

# %%
model = LogisticRegression(max_iter=1000, class_weight='balanced', fit_intercept=True) #adjust for imbalance in training data and regularization param
model.fit(X_train, Y_train)
# Out:
# LogisticRegression(class_weight='balanced', max_iter=1000)

# %%
feature_importance = pd.Series(model.coef_[0], index=X_train.columns)
feature_importance_absolute = np.abs(feature_importance)
feature_importance_absolute.sort_values(ascending=False)
# Out:
# CONTRIBUTING FACTOR VEHICLE 1_Unspecified                       5.378373e-01
# BOROUGH_MANHATTAN                                               4.955821e-01
# VEHICLE TYPE CODE 1_PASSENGER VEHICLE                           4.213636e-01
# CONTRIBUTING FACTOR VEHICLE 1_Failure to Yield Right-of-Way     3.567720e-01
# CONTRIBUTING FACTOR VEHICLE 1_Other                             2.461419e-01
# CONTRIBUTING FACTOR VEHICLE 1_Passing Too Closely               2.381276e-01
# VEHICLE TYPE CODE 1_SPORT UTILITY / STATION WAGON               2.175316e-01
# BOROUGH_QUEENS                                                  2.015125e-01
# CONTRIBUTING FACTOR VEHICLE 1_Passing or Lane Usage Improper    1.525856e-01
# VEHICLE TYPE CODE 1_Station Wagon/Sport Utility Vehicle         1.395893e-01
# VEHICLE TYPE CODE 1_Other                                       1.339537e-01
# CONTRIBUTING FACTOR VEHICLE 1_Other Vehicular                   1.225828e-01
# CONTRIBUTING FACTOR VEHICLE 1_Turning Improperly                1.193127e-01
# VEHICLE TYPE CODE 1_Box Truck                                   8.426589e-02
# CONTRIBUTING FACTOR VEHICLE 1_Fatigued/Drowsy                   8.173380e-02
# VEHICLE TYPE CODE 1_Pick-up Truck                               6.597290e-02
# BOROUGH_STATEN ISLAND                                           6.226754e-02
# VEHICLE TYPE CODE 1_VAN                                         4.440461e-02
# BOROUGH_BROOKLYN                                                4.215384e-02
# VEHICLE TYPE CODE 1_Sedan                                       2.960574e-02
# BOROUGH_Unspecified                                             2.866504e-02
# VEHICLE TYPE CODE 1_TAXI                                        2.223056e-02
# CONTRIBUTING FACTOR VEHICLE 1_Driver Inattention/Distraction    1.800342e-02
# Time from Peak Hour                                             1.256934e-02
# VEHICLE TYPE CODE 1_Taxi                                        4.645037e-03
# CONTRIBUTING FACTOR VEHICLE 1_Following Too Closely             2.189679e-03
# index                                                           1.597496e-07
# dtype: float64

# %%
feature_importance.sort_values(ascending=False)
# Out:
# CONTRIBUTING FACTOR VEHICLE 1_Unspecified                       5.378373e-01
# BOROUGH_MANHATTAN                                               4.955821e-01
# VEHICLE TYPE CODE 1_PASSENGER VEHICLE                           4.213636e-01
# CONTRIBUTING FACTOR VEHICLE 1_Passing Too Closely               2.381276e-01
# VEHICLE TYPE CODE 1_SPORT UTILITY / STATION WAGON               2.175316e-01
# BOROUGH_QUEENS                                                  2.015125e-01
# CONTRIBUTING FACTOR VEHICLE 1_Passing or Lane Usage Improper    1.525856e-01
# VEHICLE TYPE CODE 1_Station Wagon/Sport Utility Vehicle         1.395893e-01
# CONTRIBUTING FACTOR VEHICLE 1_Other Vehicular                   1.225828e-01
# CONTRIBUTING FACTOR VEHICLE 1_Turning Improperly                1.193127e-01
# VEHICLE TYPE CODE 1_Box Truck                                   8.426589e-02
# CONTRIBUTING FACTOR VEHICLE 1_Fatigued/Drowsy                   8.173380e-02
# VEHICLE TYPE CODE 1_Pick-up Truck                               6.597290e-02
# BOROUGH_STATEN ISLAND                                           6.226754e-02
# VEHICLE TYPE CODE 1_VAN                                         4.440461e-02
# BOROUGH_BROOKLYN                                                4.215384e-02
# VEHICLE TYPE CODE 1_Sedan                                       2.960574e-02
# BOROUGH_Unspecified                                             2.866504e-02
# VEHICLE TYPE CODE 1_TAXI                                        2.223056e-02
# CONTRIBUTING FACTOR VEHICLE 1_Driver Inattention/Distraction    1.800342e-02
# Time from Peak Hour                                             1.256934e-02
# VEHICLE TYPE CODE 1_Taxi                                        4.645037e-03
# CONTRIBUTING FACTOR VEHICLE 1_Following Too Closely             2.189679e-03
# index                                                          -1.597496e-07
# VEHICLE TYPE CODE 1_Other                                      -1.339537e-01
# CONTRIBUTING FACTOR VEHICLE 1_Other                            -2.461419e-01
# CONTRIBUTING FACTOR VEHICLE 1_Failure to Yield Right-of-Way    -3.567720e-01
# dtype: float64

# %%
threshold = 0.49

train_prob = model.predict_proba(X_train)[:, 1]
train_predictions = (train_prob >= threshold).astype(int)

training_accuracy = np.mean(train_predictions == Y_train)
training_accuracy
# Out:
# 0.6255256258614909

# %%
test_prob = model.predict_proba(X_test)[:, 1]
test_predictions = (test_prob >= threshold).astype(int)

test_accuracy = np.mean(test_predictions == Y_test)
test_accuracy
# Out:
# 0.624578567969303

# %%
print(classification_report(Y_train, train_predictions))
print(confusion_matrix(Y_train, train_predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.26      0.34      0.30    400169
#            1       0.78      0.71      0.74   1317783
#
#     accuracy                           0.63   1717952
#    macro avg       0.52      0.53      0.52   1717952
# weighted avg       0.66      0.63      0.64   1717952
#
# [[135675 264494]
#  [378835 938948]]

# %%
fpr, tpr, thresholds = roc_curve(Y_test, test_prob)
roc_auc = auc(fpr, tpr)

# %%
plt.figure(figsize=(15, 6))
plt.plot(fpr, tpr, color='darkorange', lw=2, label=f'ROC curve (AUC = {roc_auc:.2f})')
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend(loc='lower right')
plt.show()

# %% [markdown]
# **Conclusions:** While plots were generated to show differences in death or injury rates given different partitionings of the data, the logistic regression model seems unfit for predicting the chance of either injury or death. This may possibly be due to an absence of linear relationship between the log-odds and linear combination of features. This may also be due to the fact that we're relying mostly on one-hot-encoded features rather than numeric features and the fact that we have a highly imbalanced dataset.
#
# Further testing should be done with other models, features and methods

# %% [markdown]
# **EDA for Borough Crashes Across Time**: Here I do EDA to look into trends for the frequency of crashes actross different boroughs and attempt to build a model predicting the number of crashes.

# %%
just_QUEENS = data[data['BOROUGH'] == 'QUEENS']
just_BROOKLYN = data[data['BOROUGH'] == 'BROOKLYN']
just_BRONX = data[data['BOROUGH'] == 'BRONX']
just_MANHATTAN = data[data['BOROUGH'] == 'MANHATTAN']
just_STATEN_ISLAND = data[data['BOROUGH'] == 'STATEN ISLAND']

daily_crashes_QUEENS = just_QUEENS.groupby('CRASH DATE').size()
daily_crashes_BROOKLYN = just_BROOKLYN.groupby('CRASH DATE').size()
daily_crashes_BRONX = just_BRONX.groupby('CRASH DATE').size()
daily_crashes_MANHATTAN = just_MANHATTAN.groupby('CRASH DATE').size()
daily_crashes_STATEN_ISLAND = just_STATEN_ISLAND.groupby('CRASH DATE').size()

# %%
plt.figure(figsize=(15, 6))
plt.plot(daily_crashes_QUEENS.values, label='Daily crashes')
plt.title('Daily Motor Vehicle Collisions in Queens')
plt.xlabel('Time')
plt.ylabel('Number of Collisions')
plt.legend()
plt.show()

plt.figure(figsize=(15, 6))
plt.plot(daily_crashes_BROOKLYN.values, label='Daily crashes')
plt.title('Daily Motor Vehicle Collisions in Brooklyn')
plt.xlabel('Time')
plt.ylabel('Number of Collisions')
plt.legend()
plt.show()

plt.figure(figsize=(15, 6))
plt.plot(daily_crashes_BRONX.values, label='Daily crashes')
plt.title('Daily Motor Vehicle Collisions in the Bronx')
plt.xlabel('Time')
plt.ylabel('Number of Collisions')
plt.legend()
plt.show()

plt.figure(figsize=(15, 6))
plt.plot(daily_crashes_MANHATTAN.values, label='Daily crashes')
plt.title('Daily Motor Vehicle Collisions in Manhatten')
plt.xlabel('Time')
plt.ylabel('Number of Collisions')
plt.legend()
plt.show()

plt.figure(figsize=(15, 6))
plt.plot(daily_crashes_STATEN_ISLAND.values, label='Daily crashes')
plt.title('Daily Motor Vehicle Collisions in Staten Island')
plt.xlabel('Time')
plt.ylabel('Number of Collisions')
plt.legend()
plt.show()

# %%
# Set plot style
sns.set(style="darkgrid")

# Plot the daily crashes time series


# Decompose the time series
decomposition_QUEENS = seasonal_decompose(daily_crashes_QUEENS, model='additive', period=365)
decomposition_BROOKLYN = seasonal_decompose(daily_crashes_BROOKLYN, model='additive', period=365)
decomposition_BRONX= seasonal_decompose(daily_crashes_BRONX, model='additive', period=365)
decomposition_MANHATTAN = seasonal_decompose(daily_crashes_MANHATTAN, model='additive', period=365)
decomposition_STATEN_ISLAND = seasonal_decompose(daily_crashes_STATEN_ISLAND, model='additive', period=365)


# Plot the decomposed components
fig, ax1 = plt.subplots(1, 1, figsize=(15, 12))
decomposition_QUEENS.trend.plot(ax=ax1, label='QUEENS')
decomposition_BROOKLYN.trend.plot(ax=ax1, label='BROOKLYN')
decomposition_BRONX.trend.plot(ax=ax1, label='BRONX')
decomposition_MANHATTAN.trend.plot(ax=ax1, label='MANHATTAN')
decomposition_STATEN_ISLAND.trend.plot(ax=ax1, label='STATEN ISLAND')
ax1.set_title('Trends of Boroughs Compared')
ax1.set_xlabel('Time (Years)')
ax1.set_ylabel('Number of Collisions')
ax1.legend()

# decomposition_QUEENS.seasonal.plot(ax=ax2, label='QUEENS')
# decomposition_BROOKLYN.seasonal.plot(ax=ax2, label='BROOKLYN')
# decomposition_BRONX.seasonal.plot(ax=ax2, label='BRONX')
# decomposition_MANHATTAN.seasonal.plot(ax=ax2, label='MANHATTAN')
# decomposition_STATEN_ISLAND.seasonal.plot(ax=ax2, label='STATEN ISLAND')
# ax2.set_title('Seasons of Boroughs Compared')
# ax2.legend()

# decomposition_QUEENS.resid.plot(ax=ax3, label='QUEENS')
# decomposition_BROOKLYN.resid.plot(ax=ax3, label='BROOKLYN')
# decomposition_BRONX.resid.plot(ax=ax3, label='BRONX')
# decomposition_MANHATTAN.resid.plot(ax=ax3, label='MANHATTAN')
# decomposition_STATEN_ISLAND.resid.plot(ax=ax3, label='STATEN ISLAND')
# ax3.set_title('Residuals of Boroughs Compared')
# ax3.legend()

# %% [markdown]
# **Poisson Process:** Could we perhaps model the arrival of crashes via the poisson process? For now let's restrict our analysis to 2024.

# %%
#we will randomly select a day then see the distribution of gaps
import random

random.seed(42)
random_date = pd.Timestamp('2024-01-01') + pd.to_timedelta(random.randint(0, 364), unit='D')
sample = data[data['CRASH DATE'] == random_date]

sample['Seconds Since Midnight'] = data['CRASH TIME'].dt.hour * 60**2 + data['CRASH TIME'].dt.minute * 60 + data['CRASH TIME'].dt.second
sample = sample.sort_values(by='Seconds Since Midnight')
sample['Gap'] = sample['Seconds Since Midnight'].diff()
sample.loc[sample.index[0], 'Gap'] = 0
sample[['CRASH TIME','Seconds Since Midnight', 'Gap']]
# Out:
# <ipython-input-54-9a63ccb46a4c>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sample['Seconds Since Midnight'] = data['CRASH TIME'].dt.hour * 60**2 + data['CRASH TIME'].dt.minute * 60 + data['CRASH TIME'].dt.second
#                  CRASH TIME  Seconds Since Midnight     Gap
# 2137395 1900-01-01 00:00:00                       0     0.0
# 2137494 1900-01-01 00:00:00                       0     0.0
# 2137417 1900-01-01 00:00:00                       0     0.0
# 2137277 1900-01-01 00:00:00                       0     0.0
# 2138320 1900-01-01 00:09:00                     540   540.0
# ...                     ...                     ...     ...
# 2137738 1900-01-01 23:17:00                   83820   120.0
# 2137418 1900-01-01 23:30:00                   84600   780.0
# 2137461 1900-01-01 23:30:00                   84600     0.0
# 2137369 1900-01-01 23:50:00                   85800  1200.0
# 2137332 1900-01-01 23:50:00                   85800     0.0
#
# [222 rows x 3 columns]

# %%
from scipy import stats
from scipy.stats import poisson
from sklearn.metrics import mean_squared_error

# %%
sns.set_style("whitegrid")
plt.figure(figsize=(12, 7))

lam_test = 1 / np.mean(sample['Gap'])
t = np.arange(5000)
f = stats.expon.pdf(t, scale = 1/lam_test)

sns.histplot(data=sample, x='Gap', stat='density') #looks like an exponential distribution, lets look at some more days
plt.xlim(0, 5000)
plt.plot(t, f, color='red', lw=1)

plt.title('Distribution of Gap Sizes in a Sample of a Day from 2024', fontsize=16)
plt.xlabel('Gap (Seconds)', fontsize=14)
plt.ylabel('Density', fontsize=14)
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %%
fig, axes = plt.subplots(2, 5, figsize=(20, 8))
axes = axes.flatten()

# Loop through each day and plot the distribution
for i in range(10):  # Here we assume you want 10 days
    current_day = pd.Timestamp('2024-01-01') + pd.to_timedelta(random.randint(0, 364), unit='D')
    s = data[data['CRASH DATE'] == current_day]

    #calculate the gap between crashes in seconds
    Seconds_Since_Midnight = (s['CRASH TIME'].dt.hour * 60**2 + s['CRASH TIME'].dt.minute * 60 + s['CRASH TIME'].dt.second).sort_values()
    Gap = Seconds_Since_Midnight.diff().fillna(0)  # Calculate gap, and fill first NaN with 0

    #calculate the rate for the Poisson distribution
    lam = 1 / np.mean(Gap) if np.mean(Gap) != 0 else 1  # Prevent division by zero

    #set up the range and axies for the probability distribution plots
    t = np.arange(5000)
    f = stats.expon.pdf(t, scale=1/lam)

    #do the actual plotting
    sns.histplot(Gap.values, kde=False, stat='density', ax=axes[i])

    #add the exponential probability density function
    axes[i].plot(t, f, color='red', lw=1)

    # Set axis limits and labels
    axes[i].set_xlim(0, 5000)
    axes[i].set_title(f"Day {current_day.strftime('%Y-%m-%d')}")
    axes[i].set_xlabel('Gap (Seconds)')
    axes[i].set_ylabel('Density (%)')

# Adjust layout
plt.tight_layout()
plt.show()

# %%
#calculating lambda involving all entries in 2024
data2024 = data[data['CRASH DATE'].dt.year == 2024].sort_values(by=['CRASH DATE', 'CRASH TIME'])
Sec_Since_Midnight = data2024['CRASH TIME'].dt.hour * 60**2 + data2024['CRASH TIME'].dt.minute * 60 + data2024['CRASH TIME'].dt.second
data2024['Time Since First Crash'] = (data2024['CRASH DATE'] - data2024['CRASH DATE'].min()).dt.days * 24*60**2 + Sec_Since_Midnight
data2024['Gap'] = data2024['Time Since First Crash'].diff()
data2024.iloc[0, len(data2024.columns) - 1] = 0.0

# %%
lam_final = 1 / np.mean(data2024['Gap'])
t = np.arange(2000)
f = stats.expon.pdf(t, scale = 1/lam_final)

sns.set_style("whitegrid")
plt.figure(figsize=(12, 7))

sns.histplot(data=data2024, x='Gap', stat='density', bins= 100)
plt.xlim(0, 2000)
plt.plot(t, f, color='red', lw=1)

plt.title('Distribution of Gap Sizes Across All Entries in 2024', fontsize=16)
plt.xlabel('Gap (Seconds)', fontsize=14)
plt.ylabel('Density', fontsize=14)
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %%
#alternate plot that's more concerning
sns.set_style("whitegrid")
plt.figure(figsize=(12, 7))

sns.histplot(data=data2024, x='Gap', stat='density')
plt.xlim(0, 2000)
plt.plot(t, f, color='red', lw=1)

plt.title('Distribution of Gap Sizes Across All Entries in 2024 with Granular Bin Size', fontsize=16)
plt.xlabel('Gap (Seconds)', fontsize=14)
plt.ylabel('Density', fontsize=14)
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %% [markdown]
# So some caveats: The poisson model **seems reasonable** as most histograms plotting the distribution of gap sizes seem to follow an exponential distribution. Even when plot all of 2024's gaps, it seems gaps tend to follow a exponential distribution.
#
# However, **adjustments to bin size change the distribution of gap size to fit the exponential distribution less.** This is not unsual, having less gaps will smooth over important characteristics in the data whereas having more gaps will create bins with no values and amplify the influence of random noise. In particular in the plot of gap sizes across all of 2024's accidents with more granular bins there seems to be some regular peaking in density every 5-6 bins as seen above that's particularly suspicious. Thus **more research should be conducted to assess the viability of using a poisson process model to predict the number of crashes.**

# %%
conversion_factor = 60**2*24*365 #poisson mew for number of accidents per year
annual_expected_crashes = lam_final * conversion_factor
daily_expected_crashes = annual_expected_crashes / 365
hourly_expected_crashes = annual_expected_crashes / (24*365)
actual_num_crashes_2024 = len(data[data['CRASH DATE'].dt.year == 2024])

print(f"Expected number of crashes per year: {annual_expected_crashes}")
print(f"Expected number of crashes per day: {daily_expected_crashes}")
print(f"Expected number of crashes per hour: {hourly_expected_crashes}")
print(f"Actual number of crashes in 2024: {actual_num_crashes_2024}")
# Out:
# Expected number of crashes per year: 90759.6603512234
# Expected number of crashes per day: 248.6566037019819
# Expected number of crashes per hour: 10.360691820915914
# Actual number of crashes in 2024: 91004

# %%
#normal approximation histogram
normal_approx = np.random.normal(loc=annual_expected_crashes, scale=np.sqrt(annual_expected_crashes), size=10000)

sns.set_style("whitegrid")
plt.figure(figsize=(12, 7))

plt.hist(normal_approx, bins=50, density=True, alpha=0.6, color='g')

plt.axvline(annual_expected_crashes - np.sqrt(annual_expected_crashes), color='blue', linestyle='dashed', linewidth=2, label=f"Mean - 1 SD ({annual_expected_crashes - np.sqrt(annual_expected_crashes)})")
plt.axvline(annual_expected_crashes + np.sqrt(annual_expected_crashes), color='blue', linestyle='dashed', linewidth=2, label=f"Mean + 1 SD ({annual_expected_crashes + np.sqrt(annual_expected_crashes)})")

ci_lower = annual_expected_crashes - 1.96 * np.sqrt(annual_expected_crashes)
ci_upper = annual_expected_crashes + 1.96 * np.sqrt(annual_expected_crashes)

plt.axvline(ci_lower, color='red', linestyle='dashed', linewidth=2, label=f"95% CI Lower Bound ({ci_lower})")
plt.axvline(ci_upper, color='red', linestyle='dashed', linewidth=2, label=f"95% CI Upper Bound ({ci_upper})")

plt.title(f'Histogram of Normal Approx of General NYC Poisson Model (lambda = {annual_expected_crashes})', fontsize=16)
plt.xlabel('Counts', fontsize=14)
plt.ylabel('Density (probability per unit count)', fontsize=14)
plt.tight_layout()
plt.legend()
plt.show()

print(f"95% confidence interval : {(ci_lower, ci_upper)}")
# Out:
# 95% confidence interval : (90169.18400859377, 91350.13669385303)

# %%
#for counts of occurences in different borough I construct a red-blue process extended to the multinomial case
#chance of each borough is defined as the proportion of entries with said borough
p_QUEENS = len(data2024[data2024['BOROUGH'] == 'QUEENS']) / len(data2024)
p_BRONX = len(data2024[data2024['BOROUGH'] == 'BRONX']) / len(data2024)
p_BROOKLYN = len(data2024[data2024['BOROUGH'] == 'BROOKLYN']) / len(data2024)
p_MANHATTAN = len(data2024[data2024['BOROUGH'] == 'MANHATTAN']) / len(data2024)
p_STATEN_ISLAND = len(data2024[data2024['BOROUGH'] == 'STATEN ISLAND']) / len(data2024)
probability_vector = np.array([p_QUEENS, p_BROOKLYN, p_BRONX, p_MANHATTAN, p_STATEN_ISLAND])

# %%
name_list = ['QUEENS', 'BROOKLYN', 'BRONX', 'MANHATTAN', 'STATEN ISLAND']
expected_crashes = []
actual_crashes = []
ci = []

for i in range(5):
  name = name_list[i]
  p = probability_vector[i]

  annual_expected_crashes = lam_final * p * conversion_factor
  expected_crashes.append(annual_expected_crashes)

  daily_expected_crashes = annual_expected_crashes / 365
  hourly_expected_crashes = annual_expected_crashes / (24*365)
  actual_num_crashes_2024 = len(data2024[data2024['BOROUGH'] == name])
  actual_crashes.append(actual_num_crashes_2024)

  print(f"""======================================================{name} DATA======================================================\n""")

  nor = np.random.normal(loc=annual_expected_crashes, scale=np.sqrt(annual_expected_crashes), size=10000)

  sns.set_style("whitegrid")

  plt.hist(nor, bins=50, density=True, alpha=0.6)

  plt.axvline(annual_expected_crashes - np.sqrt(annual_expected_crashes), color='blue', linestyle='dashed', linewidth=2, label=f"Mean - 1 SD ({annual_expected_crashes - np.sqrt(annual_expected_crashes)})")
  plt.axvline(annual_expected_crashes + np.sqrt(annual_expected_crashes), color='blue', linestyle='dashed', linewidth=2, label=f"Mean + 1 SD ({annual_expected_crashes + np.sqrt(annual_expected_crashes)})")

  local_ci_lower = annual_expected_crashes - 1.96 * np.sqrt(annual_expected_crashes)
  local_ci_upper = annual_expected_crashes + 1.96 * np.sqrt(annual_expected_crashes)

  plt.axvline(local_ci_lower, color='red', linestyle='dashed', linewidth=2, label=f"95% CI Lower Bound ({local_ci_lower})")
  plt.axvline(local_ci_upper, color='red', linestyle='dashed', linewidth=2, label=f"95% CI Upper Bound ({local_ci_upper})")

  plt.title(f'Histogram of Normal Approx of {name} Poisson Model (lambda = {annual_expected_crashes})')
  plt.xlabel('Counts')
  plt.ylabel('Density (probability per unit count)')
  plt.tight_layout()
  plt.legend()
  plt.show()

  ci.append((local_ci_lower, local_ci_upper))

  print(f"95% confidence interval for expected number of crashes per year in {name}: {(local_ci_lower, local_ci_upper)}")
  print(f"Actual number of crashes in 2024 in {name}: {actual_num_crashes_2024}")
  print(f"Proportion of accidents in 2024 that happened in {name}\n(used as probability for multitype poisson process): {p}\n")


print(f"MSE incorporating 'Unspecified': {mean_squared_error(actual_crashes, expected_crashes)}")
print(f"MSE not incorporating 'Unspecified': {mean_squared_error(actual_crashes[:-1], expected_crashes[:-1])}\n")

print("NOTE: category 'Unspecified' not plotted")
# Out:
# ======================================================QUEENS DATA======================================================
# 95% confidence interval for expected number of crashes per year in QUEENS: (17458.393650179096, 17980.199938238693)
# Actual number of crashes in 2024 in QUEENS: 17767
# Proportion of accidents in 2024 that happened in QUEENS
# (used as probability for multitype poisson process): 0.19523317656366754
#
# ======================================================BROOKLYN DATA======================================================
# 95% confidence interval for expected number of crashes per year in BROOKLYN: (22345.13576487775, 22934.9629040406)
# Actual number of crashes in 2024 in BROOKLYN: 22701
# Proportion of accidents in 2024 that happened in BROOKLYN
# (used as probability for multitype poisson process): 0.24945057360116038
#
# ======================================================BRONX DATA======================================================
# 95% confidence interval for expected number of crashes per year in BRONX: (9782.35161690599, 10173.922872434921)
# Actual number of crashes in 2024 in BRONX: 10005
# Proportion of accidents in 2024 that happened in BRONX
# (used as probability for multitype poisson process): 0.10994022240780625
#
# ======================================================MANHATTAN DATA======================================================
# 95% confidence interval for expected number of crashes per year in MANHATTAN: (11567.553003653085, 11993.018137585781)
# Actual number of crashes in 2024 in MANHATTAN: 11812
# Proportion of accidents in 2024 that happened in MANHATTAN
# (used as probability for multitype poisson process): 0.1297964924618698
#
# ======================================================STATEN ISLAND DATA======================================================
# 95% confidence interval for expected number of crashes per year in STATEN ISLAND: (2573.4308297208354, 2776.1671893108814)
# Actual number of crashes in 2024 in STATEN ISLAND: 2682
# Proportion of accidents in 2024 that happened in STATEN ISLAND
# (used as probability for multitype poisson process): 0.029471232033756758
#
# MSE incorporating 'Unspecified': 1553.9692782801637
# MSE not incorporating 'Unspecified': 1929.4980318620303
#
# NOTE: category 'Unspecified' not plotted

# %%
#how many times more accidents is Brooklyn expected to have relative to Staten Island
expected_crashes[1] / expected_crashes[4]
# Out:
# 8.464205816554811

# %%
#relative to Manhattan
expected_crashes[3] / expected_crashes[4]
# Out:
# 4.404175988068606

# %%
#what percent of all expected accidents in NYC does Brooklyn make up
expected_crashes[1] / 90759.6603512234
# Out:
# 0.24945057360116044

# %%
#now Manhattan
expected_crashes[3] / 90759.6603512234
# Out:
# 0.12979649246186983

# %%
#now Staten Island
expected_crashes[4] / 90759.6603512234
# Out:
# 0.02947123203375676

# %%
sns.set_style("whitegrid")
plt.figure(figsize=(12, 7))

plt.bar(name_list, expected_crashes)

plt.title('Expected Number of Accidents by Borough', fontsize=16)
plt.xlabel('Borough', fontsize=14)
plt.ylabel('Expected Number of Accidents', fontsize=14)
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %% [markdown]
# ---

# %% [markdown]
# ##<font color='crimson'>**Milestone #6 - Virtual Poster Board Creation: Data Storytelling**</font>
#
# GOAL: The main goal of this milestone is to create a one page, virtual poster board to portray your research findings and recommendations! Your poster may be shared with the Department of Transportation and Federal Highway Authority.

# %% [markdown]
# Within your poster, summarize your research question, your reasoning for selecting your data visualization or model choices, and key insights from your data analysis. You may also wish to include your outstanding research questions that could not be answered by the dataset and why.
#
# **Be sure to answer the following on your virtual poster board:** Based on your research insights, what recommendations would you share with the Department of Transportation and Federal Highway Authority to make roads safer for vulnerable road users? Why?
#
# **Additionally, be sure to cite all relevant sources that you referred to throughout this project on your poster board (MLA or APA citation preferred). List acknowlegdments if you received any support from mentors, professors, professionals, etc. throughout your journey.**

# %% [markdown]
#  Please use the following resources to get started!
#
#
# *   [Virtual Poster Board Template](https://nebigdatahub.org/wp-content/uploads/2024/01/Copy-of-dsi-poster.ppt-48-×-36-in.pdf) - Your one-page, virtual poster may be created in PowerPoint, Google Slides, Canva, etc. Choose what you are most comfortable with!
# * [ Data Storytelling: How to Effectively Tell a Story with Data](https://online.hbs.edu/blog/post/data-storytelling)
#
# * [  Consider how your visualization(s) might appear to people with varying abilities ](https://chartability.fizz.studio/)
# *  [Understand your audience for an optimal presentation](https://hbr.org/2013/04/how-to-tell-a-story-with-data)
#
#
# Once completed, please use the [following TDSP Submission Form](https://docs.google.com/forms/d/e/1FAIpQLSeX1OSHj58EQs4ypFEPB_SH3OpWZeo67yU0WWOPVSqYtDrpWg/viewform) to share your Google Colab Notebook and your one-page, virtual project poster with the NSDC HQ Team.

# %% [markdown]
# ---
# ---

# %% [markdown]
# ## 🚗<font color='crimson'> **Thank you for completing the project!**</font> 🚗
#
# We are one step closer to making roads safer for all. [Please submit all materials to the NSDC HQ team](https://docs.google.com/forms/d/e/1FAIpQLSeX1OSHj58EQs4ypFEPB_SH3OpWZeo67yU0WWOPVSqYtDrpWg/viewform) in order to receive a certificate of completion. Do reach out to us if you have any questions or concerns. We are here to help you learn and grow.
